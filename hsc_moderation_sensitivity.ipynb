# %% [markdown]
# HSC raw mean 36.8 sd 6.7

# %%
import numpy as np

n = 15
mean = 75
sd = 13
mean_delta = 0
sd_delta = 2
school_max = 95
runs = 1000
tied = 'tied'

#### dont change below this line ####
import hsc_helpers as hh
results = hh.multi_run(n, mean, sd, mean_delta, sd_delta, school_max, runs, tied)
print(np.size(results))
hh.multi_run_plot(results, n, runs)
# Out:
# 15000
